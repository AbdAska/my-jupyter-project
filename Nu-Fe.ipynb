# %%
import numpy as np

q=9.522
de=0.00403
A=0.00953
delT=12.89
Kp=0.2 
delP=82.9
rho=998.2
v= 0.13392
le= 0.479


Nussulut_number = (q*de)/(A*delT*Kp)
skin_friction_factor = (2*de*delP)/(rho*v*v*le)
Nu_f= Nussulut_number/ skin_friction_factor
print(f'average nussulat number = {Nussulut_number:.4f}')
print(f'skin friction factor = {skin_friction_factor:.6f}')
print(f'Nu/f value = {Nu_f:.6f}')
# Out:
# average nussulat number = 1.5619
# skin friction factor = 0.077919
# Nu/f value = 20.045265

# %%
import pandas as pd

# %%
file1= pd.read_csv('Nu-delP3.csv')
file1['percentage change']= ((file1['melting-time'] - 2445)/2445)*100
file1['pressure percentage change']= ((file1['pressure drop'] - 37.90)/37.90)*100
file2= file1.loc[:6]
file3 = pd.concat([file1.iloc[:2], file1.iloc[-4:]])
file1
# Out:
#        model    flux  pressure drop  nussult number  hydraulic diameter  \
# 0       base  8.1634         37.900          1.4800              3.9048
# 1   circular  8.7736         25.080          2.2311              4.8000
# 2      R-0.5  8.3240         54.077          1.6434              4.0300
# 3     R-0.33  7.8570         81.300          1.2707              3.8200
# 4     R-0.25  7.6083        137.640          0.9071              2.9600
# 5      R-0.2  8.0190        141.900          0.9284              2.8700
# 6    R-0.167  8.2510        177.970          0.8692              2.6400
# 7        R-2  8.3150         65.940          1.5330              3.7600
# 8        R-3  9.1857         70.700          1.5859              3.9800
# 9      R-3.5  9.4780         82.900          1.5608              4.0300
# 10       R-4  8.3860         87.500          1.1506              3.2300
#
#     melting-time  percentage change  pressure percentage change
# 0         2445.0           0.000000                    0.000000
# 1         2266.3          -7.308793                  -33.825858
# 2         2392.0          -2.167689                   42.683377
# 3         2558.9           4.658487                  114.511873
# 4         2664.8           8.989775                  263.166227
# 5         2477.3           1.321063                  274.406332
# 6         2438.3          -0.274029                  369.577836
# 7         2417.2          -1.137014                   73.984169
# 8         2111.1         -13.656442                   86.543536
# 9         2060.0         -15.746421                  118.733509
# 10        2418.4          -1.087935                  130.870712

# %%
file1
# Out:
#        model    flux  pressure drop  nussult number  hydraulic diameter  \
# 0       base  8.1634         37.900          1.4800              3.9048
# 1   circular  8.7736         25.080          2.2311              4.8000
# 2      R-0.5  8.3240         54.077          1.6434              4.0300
# 3     R-0.33  7.8570         81.300          1.2707              3.8200
# 4     R-0.25  7.6083        137.640          0.9071              2.9600
# 5      R-0.2  8.0190        141.900          0.9284              2.8700
# 6    R-0.167  8.2510        177.970          0.8692              2.6400
# 7        R-2  8.3150         65.940          1.5330              3.7600
# 8        R-3  9.1857         70.700          1.5859              3.9800
# 9      R-3.5  9.4780         82.900          1.5608              4.0300
# 10       R-4  8.3860         87.500          1.1506              3.2300
#
#     melting-time  percentage change  pressure percentage change
# 0         2445.0           0.000000                    0.000000
# 1         2266.3          -7.308793                  -33.825858
# 2         2392.0          -2.167689                   42.683377
# 3         2558.9           4.658487                  114.511873
# 4         2664.8           8.989775                  263.166227
# 5         2477.3           1.321063                  274.406332
# 6         2438.3          -0.274029                  369.577836
# 7         2417.2          -1.137014                   73.984169
# 8         2111.1         -13.656442                   86.543536
# 9         2060.0         -15.746421                  118.733509
# 10        2418.4          -1.087935                  130.870712

# %%
import pandas as pd
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   model                       11 non-null     object
#  1   flux                        11 non-null     float64
#  2   pressure drop               11 non-null     float64
#  3   nussult number              11 non-null     float64
#  4   hydraulic diameter          11 non-null     float64
#  5   melting-time                11 non-null     float64
#  6   percentage change           11 non-null     float64
#  7   pressure percentage change  11 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 836.0+ bytes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22
plt.rcParams['font.weight'] = 'normal'

# Increase figure size for better visibility
fig, ax1 = plt.subplots(figsize=(10,7))  # Adjust the figure size here

# Plot the bar chart (Nusselt number)
bars = ax1.bar(file1['model'], file1['nussult number'], color='coral', label='Nusselt Number')

ax1.set_ylabel('Average Nusselt Number (Nu)')
ax1.tick_params(axis='y', length=6, width=1)
ax1.tick_params(axis='x', length=6, width=1)

# Adjust x-tick label font size
ax1.set_xticklabels(file1['model'], fontsize=22, rotation=45)  # Adjust the font size here

# Set x-axis limits to remove extra spaces
ax1.set_xlim(-0.5, len(file1['model']) - 0.5)
ax1.set_ylim(0, 2.5)

# Annotating bar values right on top of the bars
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2f}', 
             ha='center', va='bottom', fontsize=20, zorder=5)

# Create another axis for the line charts (Flux and Hydraulic Diameter)
ax2 = ax1.twinx()

# Plotting both lines (Flux and Hydraulic Diameter) on the same axis
line1, = ax2.plot(file1['model'], file1['flux'], color='red', marker='o', label='Flux')
line2, = ax2.plot(file1['model'], file1['hydraulic diameter'], color='green', marker='s')

# Setting y-axis label for the second axis
ax2.set_ylabel(r' $D_{e}$ & $\overline{Q}_{S}$ (W)')
ax2.tick_params(axis='y', length=6, width=1)
ax2.set_ylim(2.2,10)
# Annotating line values slightly below the points (add a small negative offset)
for i, value in enumerate(file1['flux']):
    ax2.text(i, value - 0.08, f'{value:.2f}', ha='center', va='top', fontsize=20, color='black', zorder=5)

# Annotating hydraulic diameter values slightly below the points
for i, value in enumerate(file1['hydraulic diameter']):
    ax2.text(i, value - 0.08, f'{value:.2f}', ha='center', va='top', fontsize=20, color='black', zorder=5)

# Creating a legend for clarity
lines = [line1, line2]
ax2.legend(lines, [r'${\overline{Q}_{S}} $ (W)', r'${D_{e}} $ (mm)'], loc='upper center', 
           fontsize=20, facecolor='lightyellow',handlelength=0.9, handletextpad=0.2, labelspacing=0.2, frameon=True, edgecolor='black')

# Title and save the plot
plt.savefig('nu-de-q.png', dpi=400, bbox_inches='tight')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25228\3777243744.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(file1['model'], fontsize=22, rotation=45)  # Adjust the font size here

# %%
# Set font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22
plt.rcParams['font.weight'] = 'normal'

# Increase figure size for better visibility
fig, ax1 = plt.subplots(figsize=(10,7.5))  # Adjust the figure size here
bar_width = 0.85  # Adjust the bar width here
bars = ax1.bar(file1['model'], file1['pressure drop'], 
               color='teal', label='Pressure Drop', zorder=2, width=bar_width)
ax1.set_xlabel('')
ax1.set_ylabel('Δ P (Pa)')




ax1.tick_params(axis='y')

ax1.set_xticklabels(file1['model'], fontsize=22, rotation=45)



for bar, pct_change in zip(bars, file1['pressure percentage change']):
    yval = bar.get_height()
    
    # Display the melting time above the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', 
             ha='center', va='bottom', fontsize=20, zorder=5)
    
    # Prepare percentage change with a positive sign for positive values
    pct_text = f'{pct_change:.1f}%' if pct_change < 0 else f'+{pct_change:.1f}%'
    
    # Choose a more visible color, such as light yellow or light green
    annotation_color = 'white'  # You can try 'lightgreen' as an alternative
    
    # Add the percentage change just below the top of the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval - 0.01 * yval, pct_text, 
             ha='center', va='top', fontsize=19, rotation=60, color=annotation_color, zorder=5)
plt.tick_params(axis='y', length=6, width=1)
plt.tick_params(axis='x', length=6, width=1)




# Set x-axis limits to remove extra spaces
ax1.set_xlim(-0.5, len(file1['model']) - 0.5)




# Title and show the plot
plt.savefig('delP.png', dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25228\2815373633.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(file1['model'], fontsize=22, rotation=45)

# %%
# Set font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22
plt.rcParams['font.weight'] = 'bold'

# Increase figure size for better visibility
fig, ax1 = plt.subplots(figsize=(10,7))  # Adjust the figure size here

# Plot the bar chart (Pressure Drop)
bars = ax1.bar(file1['model'], file1['pressure drop'], color='teal', label='Pressure Drop', zorder=2)
ax1.set_xlabel('')
ax1.set_ylabel('ΔP (Pa)', fontweight='bold')

# Annotate the bars
for bar, pct_change in zip(bars, file1['pressure percentage change']):
    yval = bar.get_height()
    
    # Display the pressure drop value above the bar
    ax1.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2f}', 
             ha='center', va='bottom', fontsize=16, zorder=5)
    
    # Prepare percentage change text
    pct_text = f'{pct_change:.1f}%' if pct_change < 0 else f'+{pct_change:.1f}%'
    
    # Add the percentage change just below the top of the bar with a fixed offset
    fixed_offset = 2.5  # Adjust this value as needed for consistent distance
    ax1.text(bar.get_x() + bar.get_width() / 2, yval - fixed_offset, pct_text, 
             ha='center', va='top', fontsize=13, color='white', weight='bold', zorder=5)

# Customize tick parameters
plt.tick_params(axis='y', length=10, width=2, pad=10)
plt.tick_params(axis='x', length=10, width=2, pad=10, labelsize=18)

# Save and show the plot
plt.savefig('delP.png', dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
# Set font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22
plt.rcParams['font.weight'] = 'normal'

# Increase figure size for better visibility
fig, ax1 = plt.subplots(figsize=(10,7))  # Adjust the figure size here

# Plot the bar chart (Melting Time)
bars = ax1.bar(file2['model'], file2['melting-time'], width=0.85, color='mediumpurple', label='Melting Time', zorder=2)

ax1.set_ylabel('t (s)')
ax1.tick_params(axis='y')
plt.tick_params(length=6, width=1)
ax1.set_ylim(0,3000)
# Annotating bar values with melting time above bars and percentage changes just below the end of bars
for bar, pct_change in zip(bars, file2['percentage change']):
    yval = bar.get_height()
    
    # Display the melting time above the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', 
             ha='center', va='bottom', fontsize=22, zorder=5)
    
    # Prepare percentage change with a positive sign for positive values
    pct_text = f'{pct_change:.1f}%' if pct_change < 0 else f'+{pct_change:.1f}%'
    
    # Choose a more visible color, such as light yellow or light green
    annotation_color = 'white'  # You can try 'lightgreen' as an alternative
    
    # Add the percentage change just below the top of the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval - 0.01 * yval, pct_text, 
             ha='center', va='top', fontsize=22, color=annotation_color, zorder=5)
plt.tight_layout()
# Title and save the plot
plt.savefig('melting_with_percentage_change1.png', dpi=400, bbox_inches='tight')

plt.show()

# %%
# Set font properties
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 22
plt.rcParams['font.weight'] = 'bold'

# Increase figure size for better visibility
fig, ax1 = plt.subplots(figsize=(15,9))  # Adjust the figure size here

# Plot the bar chart (Melting Time)
bars = ax1.bar(file3['model'], file3['melting-time'], color='mediumpurple', label='Melting Time', zorder=2)

ax1.set_ylabel('t (s)', fontweight='bold')
ax1.tick_params(axis='y')
plt.tick_params(length=10, width=2)
# Annotating bar values with melting time above bars and percentage changes just below the end of bars
for bar, pct_change in zip(bars, file3['percentage change']):
    yval = bar.get_height()
    
    # Display the melting time above the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', 
             ha='center', va='bottom', fontsize=16, zorder=5)
    
    # Prepare percentage change with a positive sign for positive values
    pct_text = f'{pct_change:.1f}%' if pct_change < 0 else f'+{pct_change:.1f}%'
    
    # Choose a more visible color, such as light yellow or light green
    annotation_color = 'white'  # You can try 'lightgreen' as an alternative
    
    # Add the percentage change just below the top of the bar
    ax1.text(bar.get_x() + bar.get_width()/2, yval - 0.01 * yval, pct_text, 
             ha='center', va='top', fontsize=16, color=annotation_color, weight='bold', zorder=5)
plt.tight_layout()
# Title and save the plot
plt.savefig('melting_with_percentage_change2.png', dpi=400, bbox_inches='tight')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import FuncFormatter, LogLocator
from PIL import Image


img = Image.open('melting_with_percentage_change1.png')
img.save('q2.bmp', format='bmp')
